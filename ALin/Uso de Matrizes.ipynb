# %% [markdown]
# # Uso simples de matrizes em encriptar imagens

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Testando para usar matrizes

# %%
v1 = np.array([4,4])
v2 = np.array([-1,-2])

# %%
#plot points
plt.scatter([0,v1[0],v1[0]+v2[0]],[0,v1[1],v1[1]+v2[1]], color="red")

#plot line
plt.plot([0,v1[0],v1[0]+v2[0]],[0,v1[1], v1[1]+v2[1]])

plt.grid(True, which='both')
plt.xticks(np.arange(-2,7,1))
plt.yticks(np.arange(-2,7,1))
plt.axvline(x=0, color="black")
plt.axhline(y=0, color="black")
plt.title("Matrix addition")
plt.show()

# %% [markdown]
# ## Encriptando uma imagem

# %% [markdown]
# A função `imread` do matplotlib consegue ler dados de uma imagem numa matriz em Numpy. Os pixeis, são representados como 8bit, inteiros sem sinal (positivo ou  negativo) dentro de uma matriz.

# %% [markdown]
# Imagem selecionada no pexels (small 640x427) [Imagem](https://www.pexels.com/photo/macro-photography-of-dragonfly-on-plant-2918152/)

# %%
# ler a foto e mostrar a ordem da matriz
foto = plt.imread("pexels-kelly-1179532-2918152.jpg")
foto.shape
# Out:
# (427, 640, 3)

# %%
plt.imshow(foto)

# %%
numero_primo = [] # usado para valores numéricos primos
for numero in  range(2,255):
    if all(numero%i != 0 for i in range(2,numero)):
        numero_primo.append(numero)

len(foto)
# Out:
# 427

# %%
numero_primo = numero_primo * len(foto)
np.random.shuffle(numero_primo)
numeros_baralhados = np.random.randint(0,255, size=len(foto))

# %%
numeros_baralhados
# Out:
# array([105,  23, 148,  15, 118,  97,  91, 155, 151, 208, 213,  78, 105,
#        142, 161, 173, 167, 126, 186, 197, 101,  45, 199, 229, 103,  22,
#         54, 131,  79, 105, 150, 105, 104, 200, 235, 241, 172,   3,  45,
#        170, 206, 173,  23, 250, 119,  63,  29, 173, 246,  62,  44, 252,
#        135,  48, 112, 136, 223, 206, 191, 113,  23, 218,  57,  24,  62,
#        115,   0, 124,  10, 141, 191, 246, 236, 187, 192,  85,  70,  32,
#         13, 181,  64,  55, 149,  51,  94, 246,  85, 217, 142,  12,   2,
#        135,  17, 141, 176, 137,  82, 109, 196, 206, 113, 146, 143,  37,
#        179, 220, 235,  62,  40, 124,  17,  44, 126, 129, 176, 234,  82,
#        194,  40, 106,  58, 111, 202, 126,  82,  69, 208, 133,  79,  18,
#        196,  93, 177, 123, 229,  49, 182,  60,  67, 200, 134,  91, 149,
#          3,  22,  19, 100,  70, 199,  12, 182,  92, 209, 254,  60,  37,
#        220,  26, 231,  80,   7, 177, 230, 207, 227, 117, 126, 157, 106,
#        239,  50, 106,  17, 100, 244, 173,  77, 112, 163,  28,   4, 168,
#        176,  86,   5, 137,   3,  29, 208,  51,  48,  51, 143, 103, 214,
#         98, 208,  17,  38,  32, 239, 164, 180, 125, 160, 143,   6,  79,
#        200, 119,  62, 251, 123,  82, 152,  25, 121, 183, 226, 242,  41,
#          4, 235, 188,  72, 171, 215, 215,  21, 133, 189,  71, 123,  70,
#         53, 136,  91, 249,  17, 203, 243, 235, 214,  59,  40,  46, 254,
#        203,  87, 218, 220,  54, 208, 206, 221, 215, 227,  40, 229, 171,
#        186,  42, 220, 190, 168,  35, 254, 223, 169, 124,  61, 103, 180,
#        204, 189,  11,  61,  72,  56, 249, 118, 161, 223, 107, 164, 220,
#         55, 210, 231,  94,   5,   9, 236, 164,  58,  51,   5, 146,   2,
#        236, 199, 242,  34, 211, 159, 246, 219, 218,  65,  47, 188, 165,
#        209,  46, 183, 179, 151,   8, 210, 100,   2,   2,   1, 228,  26,
#        130,  23, 181, 173, 179, 209,   1, 130,  17, 129, 158, 233, 160,
#        229, 128, 237,  91,  26, 150, 169, 119, 157,  54, 251,  31, 105,
#        224,  51, 169, 111, 212,  89,   6,   6, 151,  76, 108, 131, 174,
#        236, 185, 197, 111, 114,  83, 129,  37,  73, 121, 150,  27, 167,
#        129, 203,  13,  74, 139,  28, 128, 157, 198, 234, 226, 252, 157,
#         42, 197,  26, 127,  57,   6, 187, 100,  52, 130,  37, 155,  52,
#         31,  43,  53, 237, 143, 118,  83,  65,  61, 251, 230,  79,  80,
#        129, 193,  95, 203, 195, 195,  12, 163, 105,  37,  73])

# %%
foto_encriptada = np.array([(x*(x^y)) % z 
                            for x,y,z in zip(foto, numeros_baralhados, numero_primo)])

# %%
plt.imshow(foto_encriptada)
plt.show()

# %%
#assim é a imagem em uma matrix
print(foto)
# Out:
# [[[27 21  9]
#   [27 21  9]
#   [27 21  9]
#   ...
#   [31 79 31]
#   [30 80 31]
#   [30 80 31]]
#
#  [[27 21  9]
#   [27 21  9]
#   [27 21  9]
#   ...
#   [31 81 32]
#   [31 81 32]
#   [31 81 32]]
#
#  [[27 21  9]
#   [27 21  9]
#   [27 21  9]
#   ...
#   [31 81 30]
#   [31 81 30]
#   [31 81 30]]
#
#  ...
#
#  [[34 24 15]
#   [34 24 15]
#   [34 24 15]
#   ...
#   [70 86 50]
#   [67 83 47]
#   [65 81 45]]
#
#  [[34 24 15]
#   [34 24 15]
#   [34 24 15]
#   ...
#   [70 86 49]
#   [67 83 46]
#   [65 81 44]]
#
#  [[34 24 15]
#   [34 24 15]
#   [34 24 15]
#   ...
#   [70 86 49]
#   [67 83 46]
#   [65 81 44]]]
