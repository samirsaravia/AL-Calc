# %% [markdown]
# # Derivadas 3

# %%
from sympy import *
import numpy as np
import matplotlib.pyplot as plt

# %%
init_printing("mathjax")
x,t,w,y =  symbols("x t w y")

# %% [markdown]
# ## $g(x)= x \cos (x)$

# %%
g1 = x* cos(x)
g1
# Out:
# x⋅cos(x)

# %%
# Resposta
diff(g1,x)
# Out:
# -x⋅sin(x) + cos(x)

# %%
x1 = np.linspace(-1,5,30)

# %%
d1 = lambdify(x, diff(g1,x))
y1 = d1(x1)
d11 = lambdify(x, g1)
y11 = d11(x1)

# %%
def grafico(imagem, dominio1, dominio2,marker=False):
    if marker:
        plt.figure()
        plt.grid(True, which="both")
        plt.plot(imagem, dominio1, label="g(x)",marker=".")
        plt.plot(imagem, dominio2, label="g'(x)", marker=".")
        plt.legend()
        plt.show()
    else:
        plt.figure()
        plt.grid(True, which="both")
        plt.plot(imagem, dominio1, label="g(x)")
        plt.plot(imagem, dominio2, label="g'(x)")
        plt.legend()
        plt.show()

# %%
grafico(x1, y1, y11)

# %% [markdown]
# ## $h(x)=\frac{1-x^2}{x}$

# %%
h1 = (1-x**2)/x
h1
# Out:
#      2
# 1 - x
# ──────
#   x

# %%
# Resposta
diff(h1,x)
# (-1-xˆ2)/xˆ2
# Out:
#           2
#      1 - x
# -2 - ──────
#         2
#        x

# %%
h1x= np.linspace(-2,5,20)
h1f = lambdify(x,h1)
h11f = lambdify(x,diff(h1,x))

# %%
h1y = h1f(h1x)
h11y = h11f(h1x)

# %%
grafico(h1x, h1y, h11y)

# %% [markdown]
# ## $h(x)=\frac{5^x}{x}$

# %%
h2 = 5**x/x
h2
# Out:
#  x
# 5
# ──
# x

# %%
# Resposta
diff(h2,x)
# Out:
#  x           x
# 5 ⋅log(5)   5
# ───────── - ──
#     x        2
#             x

# %%
h2x = np.linspace(-3,5,40)

# %%
h2f = lambda x: 5**x
h21f = lambdify(x, diff(h2,x))

# %%
h2y = h2f(h2x)
h21y = h21f(h2x)

# %%
grafico(h2x, h2y, h21y)

# %% [markdown]
# ## $t(x)= -7x^{-2}e^x$

# %%
t1 = -7*x**-2*exp(x)
t1
# Out:
#     x
# -7⋅ℯ
# ──────
#    2
#   x

# %%
diff(t1,x)
# Out:
#      x       x
#   7⋅ℯ    14⋅ℯ
# - ──── + ─────
#     2       3
#    x       x

# %%
t1x = np.linspace(-1,1,12)
t1f = lambdify(x,t1)
t1y = t1f(t1x)

# %%
t11f = lambdify(x, diff(t1,x))
t11y = t11f(t1x)

# %%
grafico(t1x, t1y, t11y, marker=True)

# %% [markdown]
# ## $y=\frac{x^3+7}{x}$

# %%
y2 = (x**3+7)/x
y2
# Out:
#  3
# x  + 7
# ──────
#   x

# %%
diff(y2,x)
# Out:
#        3
#       x  + 7
# 3⋅x - ──────
#          2
#         x

# %%
y2x = np.linspace(-1,1,40)

# %%
y2f = lambdify(x,y2)
y21f = lambdify(x, diff(y2,x))
y2y = y2f(y2x)
y21y = y21f(y2x)

# %%
grafico(y2x, y2y, y21y)

# %% [markdown]
# ## $f(x)= 2x^2+3e^x$

# %%
f1 = 2*x**2+3*exp(x)
f1
# Out:
#    2      x
# 2⋅x  + 3⋅ℯ

# %%
diff(f1,x)
# Out:
#          x
# 4⋅x + 3⋅ℯ

# %%
f1x = np.linspace(-1,3,20)

# %%
f1f = lambdify(x,f1)
f11f = lambdify(x, diff(f1,x))
f1y = f1f(f1x)
f11y = f11f(f1x)

# %%
grafico(f1x, f1y, f11y, marker=True)

# %% [markdown]
# ## $f(x)=3xe^x$

# %%
f2 = 3*x*exp(x)
f2
# Out:
#      x
# 3⋅x⋅ℯ

# %%
diff(f2,x)
# Out:
#      x      x
# 3⋅x⋅ℯ  + 3⋅ℯ

# %%
f2x = np.linspace(1,7, 30)

# %%
f2f = lambdify(x, f2)
f21f = lambdify(x, diff(f2,x))

# %%
f2y = f2f(f2x)
f21y = f21f(f2x)

# %%
grafico(f2x, f2y, f21y, marker=True)

# %% [markdown]
# ## $f(x)=(2x+1)sen(x)$

# %%
f3 = (2*x+1)* sin(x)
f3
# Out:
# (2⋅x + 1)⋅sin(x)

# %%
diff(f3,x)
# Out:
# (2⋅x + 1)⋅cos(x) + 2⋅sin(x)

# %%
f3x = np.linspace(-3,3,40)

# %%
f3f = lambdify(x, f3)
f31f = lambdify(x, diff(f3,x))
f3y = f3f(f3x)
f31y = f31f(f3x)

# %%
grafico(f3x, f3y, f31y)

# %% [markdown]
# ## $f(x)=\frac{1}{e^x}$

# %%
f4 = 1/exp(x)
f4
# Out:
#  -x
# ℯ

# %%
diff(f4,x)
# Out:
#   -x
# -ℯ

# %%
f4x = np.linspace(4,8,30)

# %%
f4f = lambdify(x, f4)
f41f = lambdify(x, diff(f4,x))
f4y = f4f(f4x)
f41y = f41f(f4x)

# %%
grafico(f4x, f4y, f41y)

# %% [markdown]
# ## $f(x)= \frac{x^2}{3} cos(x)-3e^x$

# %%
f5 = (x**2/3)*cos(x)-3*exp(x)
f5
# Out:
#  2
# x ⋅cos(x)      x
# ───────── - 3⋅ℯ
#     3

# %%
diff(f5, x)
# Out:
#    2
#   x ⋅sin(x)   2⋅x⋅cos(x)      x
# - ───────── + ────────── - 3⋅ℯ
#       3           3

# %%
f5x = np.linspace(-3, 2,40)

# %%
f5f = lambdify(x,f5)
f51f = lambdify(x, diff(f5,x))
f5y = f5f(f5x)
f51y = f51f(f5x)

# %%
grafico(f5x, f5y, f51y,marker=True)

# %% [markdown]
# ## $y = \frac{5}{e^x cos (x)}$

# %%
y3 = 5/(exp(x)*cos(x))
y3
# Out:
#    -x
# 5⋅ℯ
# ──────
# cos(x)

# %%
diff(y3,x)
# Out:
#    -x             -x
# 5⋅ℯ  ⋅sin(x)   5⋅ℯ
# ──────────── - ──────
#      2         cos(x)
#   cos (x)

# %%
y3x = np.linspace(-2, 2, 30)

# %%
y3f = lambdify(x, y3)
y31f = lambdify(x, diff(y3, x))
y3y = y3f(y3x)
y31y = y31f(y3x)

# %%
grafico(y3x, y3y, y31y)

# %% [markdown]
# ## $y=3cos(x)sen(x)$

# %%
y4 = 3*cos(x)*sin(x)
y4
# Out:
# 3⋅sin(x)⋅cos(x)

# %%
diff(y4,x)
# Out:
#        2           2
# - 3⋅sin (x) + 3⋅cos (x)

# %%
y4x = np.linspace(-2, 4,50)

# %%
y4f = lambdify(x, y4)
y41f = lambdify(x, diff(y4,x))
y4y = y4f(y4x)
y41y = y41f(y4x)

# %%
grafico(y4x, y4y, y41y)

# %% [markdown]
# Utilizando a regra da cadeia, calcule a derivada de cada uma das funções a seguir:

# %% [markdown]
# ## $f(x)=2^{x+1}$

# %%
f6 = 2**(x+1)
f6
# Out:
#  x + 1
# 2

# %%
diff(f6, x)
# Out:
#  x + 1
# 2     ⋅log(2)

# %%
f6x = np.linspace(-1,4,20)

# %%
f6f = lambdify(x, f6)
f61f = lambdify(x, diff(f6,x))
f6y = f6f(f6x)
f61y = f61f(f6x)

# %%
grafico(f6x, f6y, f61y)

# %% [markdown]
# ## $g(x)=5x^{\frac 45}+7(x^2-3)^{-2}+12$

# %%
g2 = 5*x**(Rational(4,5))+7*(x**2-3)**(-2)+12
g2
# Out:
#    4/5            7
# 5⋅x    + 12 + ─────────
#                       2
#               ⎛ 2    ⎞
#               ⎝x  - 3⎠

# %%
diff(g2,x)
# Out:
#      28⋅x       4
# - ───────── + ─────
#           3   5 ___
#   ⎛ 2    ⎞    ╲╱ x
#   ⎝x  - 3⎠

# %%
g2x = np.linspace(1.7275,1.7375,20)

# %%
g2f = lambdify(x, g2)
g21f = lambdify(x, diff(g2,x))
g2y = g2f(g2x)
g21y = g21f(g2x)

# %%
grafico(g2x, g2y, g21y, marker=True)

# %% [markdown]
# ## $h(x)=ln(x^2+1)$

# %%
h3 = ln(x**2+1)
h3
# Out:
#    ⎛ 2    ⎞
# log⎝x  + 1⎠

# %%
diff(h3,x)
# Out:
#  2⋅x
# ──────
#  2
# x  + 1

# %%
f3x = np.linspace(-1,5,40)
f3f = lambdify(x, h3)
f31f = lambdify(x, diff(h3,x))
f3y = f3f(f3x)
f31y = f31f(f3x)

# %%
grafico(f3x, f3y, f31y)

# %% [markdown]
# ## $h(x)=sen(5x)$

# %%
h4 = sin(5*x)
h4
# Out:
# sin(5⋅x)

# %%
diff(h4,x)
# Out:
# 5⋅cos(5⋅x)

# %%
h4x = np.linspace(-2,2,50)
h4f = lambdify(x,h4)
h41f = lambdify(x, diff(h4,x))
h4y = h4f(h4x)
h41y = h41f(h4x)

# %%
grafico(h4x, h4y, h41y)

# %% [markdown]
# ## $f(x)= (x^3+x^2-2)^{\frac 34}$

# %%
j = 235*(1.06-exp(-0.00061*t))
j
# Out:
#              -0.00061⋅t
# 249.1 - 235⋅ℯ

# %%
diff(j,t).subs(t,60)
# Out:
# 0.138198242244799

# %%
jx = np.linspace(10,60,100)

# %%
jf = lambdify(t, j)
j1f = lambdify(t, diff(j,t).evalf())
jy = jf(jx)
j1y = j1f(jx)

# %%
grafico(jx, jy, j1y)

# %% [markdown]
# ## Estudo do café
# No estudo do comportamento da temperatura de
# 100 mL de café em uma caneca de alumínio
# esmaltado à temperatura ambiente de 28 0C,
# deduziu-se o seguinte modelo matemático
# $$T(t)=\frac{23.59}{1-0.61e^{-0.02t}}$$

# %% [markdown]
# Calcule a derivada da temperatura do café em função do tempo. O que essa derivada representa?

# %%
T1 = 23.59/(1-0.61*exp(-0.02*t))
T1
# Out:
#       23.59
# ─────────────────
#           -0.02⋅t
# 1 - 0.61⋅ℯ

# %%
T11 = diff(T1, t)
T11
# Out:
#            -0.02⋅t
# -0.287798⋅ℯ
# ────────────────────
#                    2
# ⎛          -0.02⋅t⎞
# ⎝1 - 0.61⋅ℯ       ⎠

# %%
T1x = np.linspace(9, 21,50)

# %%
T1f = lambdify(t, T1)
T11f = lambdify(t,T11)
T1y = T1f(T1x)
T11y = T11f(T1x)

# %%
grafico(T1x, T1y, T11y)

# %% [markdown]
# Calcule a derivada da temperatura do café para o tempo de 10 minutos. O valor obtido é positivo
# ou negativo? O que isso representa?

# %%
T11.subs(t,10)
# Out:
# -0.940355092386126

# %% [markdown]
# Calcule a derivada da temperatura do café para o tempo de 20 minutos. O valor obtido é maior
# ou menor do que o obtido no item b? O que isso representa?

# %%
T11.subs(t,20)
# Out:
# -0.552129622254872

# %% [markdown]
# ## Testando

# %%
gt = exp(-2*t)*cos(4*t)
gt
# Out:
#  -2⋅t
# ℯ    ⋅cos(4⋅t)

# %%
diff(gt, t)
# Out:
#      -2⋅t               -2⋅t
# - 4⋅ℯ    ⋅sin(4⋅t) - 2⋅ℯ    ⋅cos(4⋅t)

# %%
gtx = np.linspace(-10,-7,55)

# %%
gt1f = lambdify(t, gt.evalf())
gt11f = lambdify(t, diff(gt, t).evalf())

# %%
gty = gt1f(gtx)
gt1y = gt11f(gtx)

# %%
grafico(gtx, gty, gt1y)
